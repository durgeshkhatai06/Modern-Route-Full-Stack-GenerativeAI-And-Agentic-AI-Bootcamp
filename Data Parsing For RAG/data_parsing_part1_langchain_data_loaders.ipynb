# %%
print("all ok")
# Out:
# all ok

# %%
from langchain_community.document_loaders import (
    TextLoader,
    PyPDFLoader,
    CSVLoader,
    Docx2txtLoader,
    UnstructuredHTMLLoader,
    JSONLoader,
)

# %%
loader = PyPDFLoader("F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_document.pdf")

# %%
loader

# %%
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-04T16:55:50+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-04T16:55:50+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='LangChain PDF Loader Sample\nThis PDF is used to demonstrate PyPDFLoader in LangChain.\nRefund Policy\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\nSupport SLA\nPriority 1 tickets should receive a first response within 2 hours.\nPolicy\nOwner\nUpdate Frequency\nRefund Policy\nSupport\nQuarterly\nLeave Policy\nHR\nYearly')]

# %%
docs[0]
# Out:
# Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-04T16:55:50+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-04T16:55:50+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='LangChain PDF Loader Sample\nThis PDF is used to demonstrate PyPDFLoader in LangChain.\nRefund Policy\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\nSupport SLA\nPriority 1 tickets should receive a first response within 2 hours.\nPolicy\nOwner\nUpdate Frequency\nRefund Policy\nSupport\nQuarterly\nLeave Policy\nHR\nYearly')

# %%
docs[0].metadata
# Out:
# {'producer': 'ReportLab PDF Library - (opensource)',
#  'creator': '(unspecified)',
#  'creationdate': '2026-07-04T16:55:50+00:00',
#  'author': '(anonymous)',
#  'keywords': '',
#  'moddate': '2026-07-04T16:55:50+00:00',
#  'subject': '(unspecified)',
#  'title': '(anonymous)',
#  'trapped': '/False',
#  'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_document.pdf',
#  'total_pages': 1,
#  'page': 0,
#  'page_label': '1'}

# %%
print(docs[0].page_content)
# Out:
# LangChain PDF Loader Sample
# This PDF is used to demonstrate PyPDFLoader in LangChain.
# Refund Policy
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
# Support SLA
# Priority 1 tickets should receive a first response within 2 hours.
# Policy
# Owner
# Update Frequency
# Refund Policy
# Support
# Quarterly
# Leave Policy
# HR
# Yearly

# %%
txt_loader = TextLoader("F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_text.txt")

# %%
txt_docs = txt_loader.load()

# %%
txt_docs
# Out:
# [Document(metadata={'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_text.txt'}, page_content='LangChain Starter Parser Sample\n\nThis text file is used to demonstrate TextLoader.\n\nRAG stands for Retrieval-Augmented Generation. In a RAG pipeline, documents are parsed, split into chunks, converted into embeddings, stored in a vector database, and retrieved at query time.\n\nRefund Policy Example:\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n')]

# %%
print(txt_docs[0].metadata)
# Out:
# {'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_text.txt'}

# %%
txt_docs[0]
# Out:
# Document(metadata={'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_text.txt'}, page_content='LangChain Starter Parser Sample\n\nThis text file is used to demonstrate TextLoader.\n\nRAG stands for Retrieval-Augmented Generation. In a RAG pipeline, documents are parsed, split into chunks, converted into embeddings, stored in a vector database, and retrieved at query time.\n\nRefund Policy Example:\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n')

# %%
txt_docs[0].metadata
# Out:
# {'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_text.txt'}

# %%
{'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_text.txt'}
# Out:
# {'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_text.txt'}

# %%
print(txt_docs[0].page_content)
# Out:
# LangChain Starter Parser Sample
#
# This text file is used to demonstrate TextLoader.
#
# RAG stands for Retrieval-Augmented Generation. In a RAG pipeline, documents are parsed, split into chunks, converted into embeddings, stored in a vector database, and retrieved at query time.
#
# Refund Policy Example:
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.

# %%
csv_loader = CSVLoader("F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.csv")

# %%
csv_docs =csv_loader.load()

# %%
csv_docs[0]
# Out:
# Document(metadata={'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.csv', 'row': 0}, page_content='policy_id: P-001\ndepartment: HR\ntopic: Leave Policy\ndetails: Employees get 18 paid leaves per year.\nlast_updated: 2026-01-10')

# %%
csv_docs[0].metadata
# Out:
# {'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.csv',
#  'row': 0}

# %%
{'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.csv',
 'row': 0}
# Out:
# {'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.csv',
#  'row': 0}

# %%
print(csv_docs[0].page_content)
# Out:
# policy_id: P-001
# department: HR
# topic: Leave Policy
# details: Employees get 18 paid leaves per year.
# last_updated: 2026-01-10

# %%
json_loader =JSONLoader("F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.json",
                        jq_schema=".[]",
                        text_content=False )

# %%
docs =json_loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.json', 'seq_num': 1}, page_content='{"id": "doc-001", "title": "Refund Policy", "content": "Refunds are allowed within 7 days of purchase if the product is unused.", "metadata": {"department": "Support", "source": "policy_portal"}}'),
#  Document(metadata={'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.json', 'seq_num': 2}, page_content='{"id": "doc-002", "title": "Leave Policy", "content": "Employees receive 18 paid leaves per year and 8 sick leaves per year.", "metadata": {"department": "HR", "source": "employee_handbook"}}'),
# ...

# %%
docs[0]
# Out:
# Document(metadata={'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.json', 'seq_num': 1}, page_content='{"id": "doc-001", "title": "Refund Policy", "content": "Refunds are allowed within 7 days of purchase if the product is unused.", "metadata": {"department": "Support", "source": "policy_portal"}}')

# %%
docs[0].metadata
# Out:
# {'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_data.json',
#  'seq_num': 1}

# %%
docs[0].page_content
# Out:
# '{"id": "doc-001", "title": "Refund Policy", "content": "Refunds are allowed within 7 days of purchase if the product is unused.", "metadata": {"department": "Support", "source": "policy_portal"}}'

# %%
{"id": "doc-001", "title": "Refund Policy", "content": "Refunds are allowed within 7 days of purchase if the product is unused.", "metadata": {"department": "Support", "source": "policy_portal"}}
# Out:
# {'id': 'doc-001',
#  'title': 'Refund Policy',
#  'content': 'Refunds are allowed within 7 days of purchase if the product is unused.',
#  'metadata': {'department': 'Support', 'source': 'policy_portal'}}

# %%
html_parser = UnstructuredHTMLLoader("F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_page.html")

# %%
html_parser.load()
# Out:
# [Document(metadata={'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_page.html'}, page_content='Company Knowledge Base\n\nRefund Policy\n\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n\nSupport SLA\n\nPriority 1 tickets should receive a first response within 2 hours.\n\nChannel: Email\n\nChannel: Chat\n\nChannel: Phone')]

# %%
html_parser.load()[0].page_content
# Out:
# 'Company Knowledge Base\n\nRefund Policy\n\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n\nSupport SLA\n\nPriority 1 tickets should receive a first response within 2 hours.\n\nChannel: Email\n\nChannel: Chat\n\nChannel: Phone'

# %%
html_parser.load[0].page_content
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 html_parser.load[0].page_content
#
# TypeError: 'method' object is not subscriptable

# %%
print(html_parser.load()[0].page_content)
# Out:
# Company Knowledge Base
#
# Refund Policy
#
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
#
# Support SLA
#
# Priority 1 tickets should receive a first response within 2 hours.
#
# Channel: Email
#
# Channel: Chat
#
# Channel: Phone

# %%
docx_loader = Docx2txtLoader("F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_document.docx")

# %%
docx_loader.load()
# Out:
# [Document(metadata={'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample_document.docx'}, page_content='LangChain DOCX Loader Sample\n\nThis document is used to demonstrate Docx2txtLoader in LangChain.\n\nRefund Policy\n\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n\nLeave Policy\n\nEmployees receive 18 paid leaves per year and 8 sick leaves per year.\n\nSimple Table\n\nPolicy\n\nOwner\n\nUpdate Frequency\n\nRefund Policy\n\nSupport\n\nQuarterly\n\nLeave Policy\n\nHR\n\nYearly')]

# %%
from langchain_community.document_loaders import UnstructuredMarkdownLoader

# %%
md_loader =UnstructuredMarkdownLoader("F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample.md")

# %%
md_loader.load()
# Out:
# [Document(metadata={'source': 'F:\\Modern-Route-Full-Stack-GenerativeAI-And-Agentic-AI-Bootcamp\\data\\sample.md'}, page_content='Enterprise RAG System: Complete Sample Markdown Document\n\n1. Introduction\n\nRetrieval-Augmented Generation, commonly known as RAG, is a technique used to connect Large Language Models with external knowledge sources. Instead of depending only on the knowledge stored inside the model during training, RAG allows the system to retrieve relevant information from documents, databases, websites, or other sources at runtime.\n\nThis makes RAG very useful for enterprise applications where the data is private, frequently changing, or too large to fit inside the model context directly.\n\nIn simple terms:\n\nRAG does not train the model. RAG gives the model the right context before answering.\n\n2. Why RAG is Needed\n\nLarge Language Models are powerful, but they have limitations.\n\n2.1 LLMs Do Not Know Private Data\n\nA normal LLM does not automatically know yo
# ...

# %%
print(md_loader.load()[0].page_content)
# Out:
# Enterprise RAG System: Complete Sample Markdown Document
#
# 1. Introduction
#
# Retrieval-Augmented Generation, commonly known as RAG, is a technique used to connect Large Language Models with external knowledge sources. Instead of depending only on the knowledge stored inside the model during training, RAG allows the system to retrieve relevant information from documents, databases, websites, or other sources at runtime.
#
# This makes RAG very useful for enterprise applications where the data is private, frequently changing, or too large to fit inside the model context directly.
#
# In simple terms:
#
# RAG does not train the model. RAG gives the model the right context before answering.
#
# 2. Why RAG is Needed
#
# Large Language Models are powerful, but they have limitations.
#
# 2.1 LLMs Do Not Know Private Data
#
# ...
