# %%
1+1
# Out:
# 2

# %%
4*5
# Out:
# 20

# %%
2*10
# Out:
# 20

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
10**2
# Out:
# 100

# %%
type(True)
# Out:
# bool

# %%
type("Hello")
# Out:
# str

# %%
type("Hello")
# Out:
# str

# %%
"Hello"
# Out:
# 'Hello'

# %%
'Krish Naik'
# Out:
# 'Krish Naik'

# %%
type("Krish Naik")
# Out:
# str

# %%
# syntax
# var_name=values

a=10

# %%
type(a)
# Out:
# int

# %%
a='Krish Naik'

# %%
type(a)
# Out:
# str

# %%
## Mathematical operation with Variable Assigment

a=10
b=20

# %%
print(a*b)
print(a/b)
print(a%b)
print((a*b)+(a/b)) ##BODMAS
# Out:
# 200
# 0.5
# 10
# 200.5

# %%
## Various Ways of Printing

print("Hello")
# Out:
# Hello

# %%
first_name='Krish'
last_name='Naik'
