# %%
1+1
# Out:
# 2

# %%
4*5
# Out:
# 20

# %%
2*10
# Out:
# 20

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
10**2
# Out:
# 100

# %%
type(True)
# Out:
# bool

# %%
type("Hello")
# Out:
# str

# %%
type("Hello")
# Out:
# str

# %%
"Hello"
# Out:
# 'Hello'
