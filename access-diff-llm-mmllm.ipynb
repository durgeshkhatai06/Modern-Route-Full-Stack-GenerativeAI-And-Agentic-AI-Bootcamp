# %%
print("all ok")
# Out:
# all ok

# %%
import os
OPENAI_API_KEY = os.getenv ("OPENAI_API_KEY")  # This will return None if the environment variable is not set
if OPENAI_API_KEY:
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-5-nano")

# %%
message = llm.invoke("What is the capital of India?")

# %%
message
# Out:
# AIMessage(content='New Delhi.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 332, 'prompt_tokens': 13, 'total_tokens': 345, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DifuvycJXCWkzRudFASLSP4hBTlpg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e54d8-6c89-7f03-867c-a7fe792d8237-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 332, 'total_tokens': 345, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})
