# %%
# !pip install crewai crewai-tools opik --upgrade
# Out:
# Requirement already satisfied: crewai in j:\anaconda\lib\site-packages (1.14.2)
# Collecting crewai-tools
#   Using cached crewai_tools-1.14.2-py3-none-any.whl.metadata (11 kB)
# Collecting opik
#   Downloading opik-2.0.1-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: aiofiles~=24.1.0 in j:\anaconda\lib\site-packages (from crewai) (24.1.0)
# Requirement already satisfied: aiosqlite~=0.21.0 in j:\anaconda\lib\site-packages (from crewai) (0.21.0)
# Requirement already satisfied: appdirs~=1.4.4 in j:\anaconda\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: chromadb~=1.1.0 in j:\anaconda\lib\site-packages (from crewai) (1.1.1)
# Requirement already satisfied: click~=8.1.7 in j:\anaconda\lib\site-packages (from crewai) (8.1.8)
# Requirement already satisfied: httpx~=0.28.1 in j:\anaconda\lib\site-packages (from crewai) (0.28.1)
# Requirement already satisfied: instructor>=1.3.3 in j:\anaconda\lib\site-packages (from crewai) (1.15.1)
# Requirement already satisfied: json-repair~=0.25.2 in j:\anaconda\lib\site-packages (from crewai) (0.25.3)
# Requirement already satisfied: json5~=0.10.0 in j:\anaconda\lib\site-packages (from crewai) (0.10.0)
# Requirement already satisfied: jsonref~=1.1.0 in j:\anaconda\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: lancedb<0.30.1,>=0.29.2 in j:\anaconda\lib\site-packages (from crewai) (0.30.0)
# Requirement already satisfied: mcp~=1.26.0 in j:\anaconda\lib\site-packages (from crewai) (1.26.0)
# Requirement already satisfied: openai<3,>=2.0.0 in j:\anaconda\lib\site-packages (from crewai) (2.32.0)
# Requirement already satisfied: openpyxl~=3.1.5 in j:\anaconda\lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api~=1.34.0 in j:\anaconda\lib\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http~=1.34.0 in j:\anaconda\lib\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk~=1.34.0 in j:\anaconda\lib\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: pdfplumber~=0.11.4 in j:\anaconda\lib\site-packages (from crewai) (0.11.9)
# Requirement already satisfied: portalocker~=2.7.0 in j:\anaconda\lib\site-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic-settings~=2.10.1 in j:\anaconda\lib\site-packages (from crewai) (2.10.1)
# Requirement already satisfied: pydantic~=2.11.9 in j:\anaconda\lib\site-packages (from crewai) (2.11.10)
# Requirement already satisfied: pyjwt<3,>=2.9.0 in j:\anaconda\lib\site-packages (from crewai) (2.10.1)
# Requirement already satisfied: python-dotenv~=1.1.1 in j:\anaconda\lib\site-packages (from crewai) (1.1.1)
# Requirement already satisfied: pyyaml~=6.0 in j:\anaconda\lib\site-packages (from crewai) (6.0.2)
# Requirement already satisfied: regex~=2026.1.15 in j:\anaconda\lib\site-packages (from crewai) (2026.1.15)
# Requirement already satisfied: textual>=7.5.0 in j:\anaconda\lib\site-packages (from crewai) (8.2.3)
# Requirement already satisfied: tokenizers<1,>=0.21 in j:\anaconda\lib\site-packages (from crewai) (0.22.2)
# Requirement already satisfied: tomli-w~=1.1.0 in j:\anaconda\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: tomli~=2.0.2 in j:\anaconda\lib\site-packages (from crewai) (2.0.2)
# Requirement already satisfied: uv~=0.11.6 in j:\anaconda\lib\site-packages (from crewai) (0.11.7)
# Requirement already satisfied: typing_extensions>=4.0 in j:\anaconda\lib\site-packages (from aiosqlite~=0.21.0->crewai) (4.15.0)
# Requirement already satisfied: build>=1.0.3 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (1.4.3)
# Requirement already satisfied: pybase64>=1.4.1 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in j:\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.44.0)
# Requirement already satisfied: numpy>=1.22.5 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (2.1.3)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (1.24.4)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (1.34.1)
# Requirement already satisfied: pypika>=0.48.9 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (7.4.0)
# Requirement already satisfied: importlib-resources in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (9.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (3.11.7)
# Requirement already satisfied: rich>=10.11.0 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (14.3.4)
# Requirement already satisfied: jsonschema>=4.19.0 in j:\anaconda\lib\site-packages (from chromadb~=1.1.0->crewai) (4.23.0)
# Requirement already satisfied: colorama in j:\anaconda\lib\site-packages (from click~=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: anyio in j:\anaconda\lib\site-packages (from httpx~=0.28.1->crewai) (4.7.0)
# Requirement already satisfied: certifi in j:\anaconda\lib\site-packages (from httpx~=0.28.1->crewai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in j:\anaconda\lib\site-packages (from httpx~=0.28.1->crewai) (1.0.9)
# Requirement already satisfied: idna in j:\anaconda\lib\site-packages (from httpx~=0.28.1->crewai) (3.7)
# Requirement already satisfied: h11>=0.16 in j:\anaconda\lib\site-packages (from httpcore==1.*->httpx~=0.28.1->crewai) (0.16.0)
# Requirement already satisfied: deprecation>=2.1.0 in j:\anaconda\lib\site-packages (from lancedb<0.30.1,>=0.29.2->crewai) (2.1.0)
# Requirement already satisfied: packaging>=23.0 in j:\anaconda\lib\site-packages (from lancedb<0.30.1,>=0.29.2->crewai) (24.2)
# Requirement already satisfied: pyarrow>=16 in j:\anaconda\lib\site-packages (from lancedb<0.30.1,>=0.29.2->crewai) (19.0.0)
# Requirement already satisfied: lance-namespace>=0.3.2 in j:\anaconda\lib\site-packages (from lancedb<0.30.1,>=0.29.2->crewai) (0.6.1)
# Requirement already satisfied: httpx-sse>=0.4 in j:\anaconda\lib\site-packages (from mcp~=1.26.0->crewai) (0.4.0)
# Requirement already satisfied: python-multipart>=0.0.9 in j:\anaconda\lib\site-packages (from mcp~=1.26.0->crewai) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\user\appdata\roaming\python\python313\site-packages (from mcp~=1.26.0->crewai) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in j:\anaconda\lib\site-packages (from mcp~=1.26.0->crewai) (3.3.4)
# Requirement already satisfied: starlette>=0.27 in j:\anaconda\lib\site-packages (from mcp~=1.26.0->crewai) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in j:\anaconda\lib\site-packages (from mcp~=1.26.0->crewai) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in j:\anaconda\lib\site-packages (from openai<3,>=2.0.0->crewai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in j:\anaconda\lib\site-packages (from openai<3,>=2.0.0->crewai) (0.11.1)
# Requirement already satisfied: sniffio in j:\anaconda\lib\site-packages (from openai<3,>=2.0.0->crewai) (1.3.0)
# Requirement already satisfied: et-xmlfile in j:\anaconda\lib\site-packages (from openpyxl~=3.1.5->crewai) (1.1.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in j:\anaconda\lib\site-packages (from opentelemetry-api~=1.34.0->crewai) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in j:\anaconda\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.34.0->crewai) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in j:\anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in j:\anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in j:\anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.34.1)
# Requirement already satisfied: requests~=2.7 in j:\anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (2.33.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in j:\anaconda\lib\site-packages (from opentelemetry-proto==1.34.1->opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (5.29.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in j:\anaconda\lib\site-packages (from opentelemetry-sdk~=1.34.0->crewai) (0.55b1)
# Requirement already satisfied: pdfminer.six==20251230 in j:\anaconda\lib\site-packages (from pdfplumber~=0.11.4->crewai) (20251230)
# Requirement already satisfied: Pillow>=9.1 in j:\anaconda\lib\site-packages (from pdfplumber~=0.11.4->crewai) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in j:\anaconda\lib\site-packages (from pdfplumber~=0.11.4->crewai) (5.7.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in j:\anaconda\lib\site-packages (from pdfminer.six==20251230->pdfplumber~=0.11.4->crewai) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in j:\anaconda\lib\site-packages (from pdfminer.six==20251230->pdfplumber~=0.11.4->crewai) (44.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in j:\anaconda\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in j:\anaconda\lib\site-packages (from pydantic~=2.11.9->crewai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in j:\anaconda\lib\site-packages (from pydantic~=2.11.9->crewai) (2.33.2)
# Requirement already satisfied: urllib3<3,>=1.26 in j:\anaconda\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (2.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in j:\anaconda\lib\site-packages (from tokenizers<1,>=0.21->crewai) (1.11.0)
# Requirement already satisfied: filelock>=3.10.0 in j:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in j:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in j:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (1.4.3)
# Collecting beautifulsoup4~=4.13.4 (from crewai-tools)
#   Using cached beautifulsoup4-4.13.5-py3-none-any.whl.metadata (3.8 kB)
# Collecting pymupdf~=1.26.6 (from crewai-tools)
#   Using cached pymupdf-1.26.7-cp310-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting python-docx~=1.2.0 (from crewai-tools)
#   Using cached python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pytube~=15.0.0 (from crewai-tools)
#   Using cached pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting tiktoken~=0.8.0 (from crewai-tools)
#   Downloading tiktoken-0.8.0-cp313-cp313-win_amd64.whl.metadata (6.8 kB)
# Collecting youtube-transcript-api~=1.2.2 (from crewai-tools)
#   Using cached youtube_transcript_api-1.2.4-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: soupsieve>1.2 in j:\anaconda\lib\site-packages (from beautifulsoup4~=4.13.4->crewai-tools) (2.5)
# Requirement already satisfied: lxml>=3.1.0 in j:\anaconda\lib\site-packages (from python-docx~=1.2.0->crewai-tools) (6.0.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in j:\anaconda\lib\site-packages (from youtube-transcript-api~=1.2.2->crewai-tools) (0.7.1)
# Collecting boto3-stubs>=1.34.110 (from boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading boto3_stubs-1.42.91-py3-none-any.whl.metadata (155 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from opik)
#   Downloading rapidfuzz-3.14.5-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: litellm!=1.75.0,!=1.75.1,!=1.75.2,!=1.75.3,!=1.75.4,!=1.75.5,!=1.77.3,!=1.77.4,!=1.77.5,!=1.77.7,!=1.78.0,!=1.78.2,!=1.78.3,!=1.78.4,!=1.78.5,!=1.78.6,!=1.78.7,!=1.79.0,!=1.79.1,>=1.79.2 in j:\anaconda\lib\site-packages (from opik) (1.83.0)
# Requirement already satisfied: pytest in j:\anaconda\lib\site-packages (from opik) (7.4.4)
# Requirement already satisfied: sentry_sdk>=2.0.0 in j:\anaconda\lib\site-packages (from opik) (2.18.0)
# Collecting uuid6 (from opik)
#   Downloading uuid6-2025.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jinja2 in j:\anaconda\lib\site-packages (from opik) (3.1.6)
# Requirement already satisfied: watchfiles<2.0.0,>=1.0.0 in j:\anaconda\lib\site-packages (from opik) (1.1.1)
# Collecting tree-sitter<1.0,>=0.23 (from opik)
#   Downloading tree_sitter-0.25.2-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Collecting tree-sitter-javascript<1.0,>=0.23 (from opik)
#   Downloading tree_sitter_javascript-0.25.0-cp310-abi3-win_amd64.whl.metadata (2.3 kB)
# Collecting tree-sitter-typescript<1.0,>=0.23 (from opik)
#   Downloading tree_sitter_typescript-0.23.2-cp39-abi3-win_amd64.whl.metadata (2.4 kB)
# Collecting botocore-stubs (from boto3-stubs>=1.34.110->boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading botocore_stubs-1.42.41-py3-none-any.whl.metadata (3.4 kB)
# Collecting types-s3transfer (from boto3-stubs>=1.34.110->boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading types_s3transfer-0.16.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting mypy-boto3-bedrock-runtime<1.43.0,>=1.42.0 (from boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading mypy_boto3_bedrock_runtime-1.42.82-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyproject_hooks in j:\anaconda\lib\site-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in j:\anaconda\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber~=0.11.4->crewai) (1.17.1)
# Requirement already satisfied: pycparser in j:\anaconda\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber~=0.11.4->crewai) (2.21)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in j:\anaconda\lib\site-packages (from instructor>=1.3.3->crewai) (3.11.10)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in j:\anaconda\lib\site-packages (from instructor>=1.3.3->crewai) (0.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in j:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in j:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in j:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in j:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in j:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in j:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in j:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in j:\anaconda\lib\site-packages (from jinja2->opik) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in j:\anaconda\lib\site-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (2.19.2)
# Requirement already satisfied: shellingham>=1.3.0 in j:\anaconda\lib\site-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (1.5.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in j:\anaconda\lib\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in j:\anaconda\lib\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in j:\anaconda\lib\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.22.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in j:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in j:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in j:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.10)
# Requirement already satisfied: lance-namespace-urllib3-client==0.6.1 in j:\anaconda\lib\site-packages (from lance-namespace>=0.3.2->lancedb<0.30.1,>=0.29.2->crewai) (0.6.1)
# Requirement already satisfied: fastuuid>=0.13.0 in j:\anaconda\lib\site-packages (from litellm!=1.75.0,!=1.75.1,!=1.75.2,!=1.75.3,!=1.75.4,!=1.75.5,!=1.77.3,!=1.77.4,!=1.77.5,!=1.77.7,!=1.78.0,!=1.78.2,!=1.78.3,!=1.78.4,!=1.78.5,!=1.78.6,!=1.78.7,!=1.79.0,!=1.79.1,>=1.79.2->opik) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in j:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb~=1.1.0->crewai) (0.1.0)
# Requirement already satisfied: flatbuffers in j:\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (25.12.19)
# Requirement already satisfied: sympy in j:\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.13.3)
# Requirement already satisfied: mdit-py-plugins in j:\anaconda\lib\site-packages (from textual>=7.5.0->crewai) (0.3.0)
# Requirement already satisfied: platformdirs<5,>=3.6.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from textual>=7.5.0->crewai) (4.4.0)
# Requirement already satisfied: linkify-it-py<3,>=1 in j:\anaconda\lib\site-packages (from markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai) (2.0.0)
# Requirement already satisfied: uc-micro-py in j:\anaconda\lib\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai) (1.0.1)
# Requirement already satisfied: httptools>=0.6.3 in j:\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.7.1)
# Requirement already satisfied: websockets>=10.4 in j:\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (16.0)
# Collecting types-awscrt (from botocore-stubs->boto3-stubs>=1.34.110->boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading types_awscrt-0.31.3-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: iniconfig in j:\anaconda\lib\site-packages (from pytest->opik) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in j:\anaconda\lib\site-packages (from pytest->opik) (1.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in j:\anaconda\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in j:\anaconda\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.3.0)
# Using cached crewai_tools-1.14.2-py3-none-any.whl (784 kB)
# Using cached beautifulsoup4-4.13.5-py3-none-any.whl (105 kB)
# Using cached pymupdf-1.26.7-cp310-abi3-win_amd64.whl (18.4 MB)
# Using cached python_docx-1.2.0-py3-none-any.whl (252 kB)
# Using cached pytube-15.0.0-py3-none-any.whl (57 kB)
# Downloading tiktoken-0.8.0-cp313-cp313-win_amd64.whl (883 kB)
#    ---------------------------------------- 0.0/883.8 kB ? eta -:--:--
#    --------------------------------------- 883.8/883.8 kB 29.6 MB/s eta 0:00:00
# Using cached youtube_transcript_api-1.2.4-py3-none-any.whl (485 kB)
# Downloading opik-2.0.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------- ----------- 1.0/1.5 MB 85.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 4.6 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.5-cp313-cp313-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 55.0 MB/s eta 0:00:00
# Downloading tree_sitter-0.25.2-cp313-cp313-win_amd64.whl (127 kB)
# Downloading tree_sitter_javascript-0.25.0-cp310-abi3-win_amd64.whl (62 kB)
# Downloading tree_sitter_typescript-0.23.2-cp39-abi3-win_amd64.whl (278 kB)
# Downloading boto3_stubs-1.42.91-py3-none-any.whl (70 kB)
# Downloading mypy_boto3_bedrock_runtime-1.42.82-py3-none-any.whl (36 kB)
# Downloading botocore_stubs-1.42.41-py3-none-any.whl (66 kB)
# Downloading types_awscrt-0.31.3-py3-none-any.whl (43 kB)
# Downloading types_s3transfer-0.16.0-py3-none-any.whl (19 kB)
# Downloading uuid6-2025.0.1-py3-none-any.whl (7.0 kB)
# Installing collected packages: uuid6, types-s3transfer, types-awscrt, tree-sitter-typescript, tree-sitter-javascript, tree-sitter, rapidfuzz, pytube, python-docx, pymupdf, mypy-boto3-bedrock-runtime, beautifulsoup4, youtube-transcript-api, tiktoken, botocore-stubs, boto3-stubs, opik, crewai-tools
#
#    -------- -------------------------------  4/18 [tree-sitter-javascript]
#    ------------- --------------------------  6/18 [rapidfuzz]
#    ------------- --------------------------  6/18 [rapidfuzz]
#    ------------- --------------------------  6/18 [rapidfuzz]
#    ------------- --------------------------  6/18 [rapidfuzz]
#    --------------- ------------------------  7/18 [pytube]
#    --------------- ------------------------  7/18 [pytube]
#    --------------- ------------------------  7/18 [pytube]
#    --------------- ------------------------  7/18 [pytube]
#    ----------------- ----------------------  8/18 [python-docx]
#    ----------------- ----------------------  8/18 [python-docx]
#    ----------------- ----------------------  8/18 [python-docx]
#    ----------------- ----------------------  8/18 [python-docx]
#    ----------------- ----------------------  8/18 [python-docx]
#    ----------------- ----------------------  8/18 [python-docx]
#    ----------------- ----------------------  8/18 [python-docx]
#    ----------------- ----------------------  8/18 [python-docx]
#    ----------------- ----------------------  8/18 [python-docx]
#    -------------------- -------------------  9/18 [pymupdf]
#    -------------------- -------------------  9/18 [pymupdf]
#    -------------------- -------------------  9/18 [pymupdf]
#    -------------------- -------------------  9/18 [pymupdf]
#    -------------------- -------------------  9/18 [pymupdf]
#    -------------------- -------------------  9/18 [pymupdf]
#    -------------------- -------------------  9/18 [pymupdf]
#    ---------------------- ----------------- 10/18 [mypy-boto3-bedrock-runtime]
#   Attempting uninstall: beautifulsoup4
#    ---------------------- ----------------- 10/18 [mypy-boto3-bedrock-runtime]
#     Found existing installation: beautifulsoup4 4.14.3
#    ---------------------- ----------------- 10/18 [mypy-boto3-bedrock-runtime]
#     Uninstalling beautifulsoup4-4.14.3:
#    ---------------------- ----------------- 10/18 [mypy-boto3-bedrock-runtime]
#       Successfully uninstalled beautifulsoup4-4.14.3
#    ---------------------- ----------------- 10/18 [mypy-boto3-bedrock-runtime]
#    ------------------------ --------------- 11/18 [beautifulsoup4]
#    ------------------------ --------------- 11/18 [beautifulsoup4]
#    -------------------------- ------------- 12/18 [youtube-transcript-api]
#    -------------------------- ------------- 12/18 [youtube-transcript-api]
#    -------------------------- ------------- 12/18 [youtube-transcript-api]
#    -------------------------- ------------- 12/18 [youtube-transcript-api]
#   Attempting uninstall: tiktoken
#    -------------------------- ------------- 12/18 [youtube-transcript-api]
#     Found existing installation: tiktoken 0.12.0
#    -------------------------- ------------- 12/18 [youtube-transcript-api]
#     Uninstalling tiktoken-0.12.0:
#    -------------------------- ------------- 12/18 [youtube-transcript-api]
#       Successfully uninstalled tiktoken-0.12.0
#    -------------------------- ------------- 12/18 [youtube-transcript-api]
#    ---------------------------- ----------- 13/18 [tiktoken]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ----------------------------------- ---- 16/18 [opik]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ------------------------------------- -- 17/18 [crewai-tools]
#    ---------------------------------------- 18/18 [crewai-tools]
#
# Successfully installed beautifulsoup4-4.13.5 boto3-stubs-1.42.91 botocore-stubs-1.42.41 crewai-tools-1.14.2 mypy-boto3-bedrock-runtime-1.42.82 opik-2.0.1 pymupdf-1.26.7 python-docx-1.2.0 pytube-15.0.0 rapidfuzz-3.14.5 tiktoken-0.8.0 tree-sitter-0.25.2 tree-sitter-javascript-0.25.0 tree-sitter-typescript-0.23.2 types-awscrt-0.31.3 types-s3transfer-0.16.0 uuid6-2025.0.1 youtube-transcript-api-1.2.4
# WARNING: Ignoring invalid distribution ~ydantic-core (J:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ydantic-core (J:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ydantic-core (J:\Anaconda\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 6.0.7 requires ipython!=8.17.1,<9.0.0,>=8.13.0; python_version > "3.8", but you have ipython 9.5.0 which is incompatible.

# %%
import opik
opik.configure(use_local=False)
# Out:
# OPIK: Your Opik API key is available in your account settings, can be found at https://www.comet.com/api/my/settings/ for Opik cloud
# OPIK: Configuration saved to file: C:\Users\USER\.opik.config
# OPIK: Configuration completed successfully. Traces will be logged to 'crewai-opik-integration' project. To change the destination project, see: https://www.comet.com/docs/opik/tracing/log_traces#configuring-the-project-name

# %% [markdown]
# ##### Using CrewAI

# %%
from crewai import Agent, Crew, Task, Process


class YourCrewName:
    def agent_one(self) -> Agent:
        return Agent(
            role="Data Analyst",
            goal="Analyze data trends in the market",
            backstory="An experienced data analyst with a background in economics",
            verbose=True,
        )

    def agent_two(self) -> Agent:
        return Agent(
            role="Market Researcher",
            goal="Gather information on market dynamics",
            backstory="A diligent researcher with a keen eye for detail",
            verbose=True,
        )

    def task_one(self) -> Task:
        return Task(
            name="Collect Data Task",
            description="Collect recent market data and identify trends.",
            expected_output="A report summarizing key trends in the market.",
            agent=self.agent_one(),
        )

    def task_two(self) -> Task:
        return Task(
            name="Market Research Task",
            description="Research factors affecting market dynamics.",
            expected_output="An analysis of factors influencing the market.",
            agent=self.agent_two(),
        )

    def crew(self) -> Crew:
        return Crew(
            agents=[self.agent_one(), self.agent_two()],
            tasks=[self.task_one(), self.task_two()],
            process=Process.sequential,
            verbose=True,
        )
